# %% [markdown]
# ---
#
# #  yticks_spacing_issue420
#
# ---

# %%
# This allows multiple outputs from a single jupyter notebook cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline
import pandas as pd

# %%
import mplfinance as mpf
mpf.__version__
# Out:
# '0.12.7a18'

# %%
df = pd.read_csv('../data/SP500_NOV2019_Hist.csv',index_col=0,parse_dates=True)

# %%
fig, axlist = mpf.plot(df,type='candle',show_nontrading=True,returnfig=True)#,volume=True)

# %%
yticks = [3060,3070,3080,3090,3100,3110,3120,3130,3140,3150]

# %%
axlist[0].set_yticks(yticks)

# %%
axlist[-2].set_xlabel('Date')
# Out:
# Text(0.5, 4.4444444444444375, 'Date')

# %%
len(axlist)
# Out:
# 2

# %%
fig

# %%
ylimits=(1908,1950)

# %%
yticks = [ yt for yt in range(ylimits[0],ylimits[-1],2)]
yticks
# Out:
# [1908,
#  1910,
#  1912,
#  1914,
#  1916,
#  1918,
#  1920,
#  1922,
#  1924,
#  1926,
#  1928,
#  1930,
#  1932,
#  1934,
#  1936,
#  1938,
#  1940,
#  1942,
#  1944,
#  1946,
#  1948]
